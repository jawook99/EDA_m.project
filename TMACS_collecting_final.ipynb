# %%
import os
import time
import pandas as pd
import logging
import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoAlertPresentException, TimeoutException, StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.chrome.options import Options

# ---------------------- 로그 설정 ----------------------
log_file_name = f"crawling_log_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
logging.basicConfig(
    filename=log_file_name,
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    encoding='utf-8'
)
console_handler = logging.StreamHandler()
console_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))
logging.getLogger().addHandler(console_handler)

DOWNLOAD_DIR = r"C:\Users\USER\Downloads"
options = Options()
options.add_experimental_option("detach", True)
options.add_experimental_option("prefs", {
    "download.default_directory": DOWNLOAD_DIR,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "plugins.always_open_pdf_externally": True
})

driver = webdriver.Chrome(options=options)
driver.get("https://tmacs.kotsa.or.kr/web/TG/TG300/TG3100/Tg2127.jsp?mid=S1810")
wait = WebDriverWait(driver, 15)

# ---------------------- 팝업 / 다운로드 ----------------------
def wait_for_download_complete(download_dir=DOWNLOAD_DIR, timeout=180):
    before = set(os.listdir(download_dir))
    end_time = time.time() + timeout
    while time.time() < end_time:
        after = set(os.listdir(download_dir))
        new_files = after - before
        if new_files and any(f.endswith((".xlsx", ".xls")) for f in new_files):
            for f in new_files:
                if (f.endswith(".xlsx") or f.endswith(".xls")) and not f.startswith("~"):
                    return f
        time.sleep(1)
     # 타임아웃 오류 메시지 추가
    raise TimeoutError(f"파일 다운로드 시간 초과. {timeout}초 내에 .xlsx 또는 .xls 파일을 찾을 수 없습니다.")


def handle_structure_download(driver, wait, key):
    main_window = driver.current_window_handle
    retries = 0
    while retries < 2:
        try:
            time.sleep(1)
            for handle in driver.window_handles:
                if handle != main_window:
                    driver.switch_to.window(handle)
                    break
            
            tab = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#tabId03")))
            tab.click()
            time.sleep(5)

            wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "dl.jogun dd")))
            dd_elements = driver.find_elements(By.CSS_SELECTOR, "dl.jogun dd")
            사고지역 = dd_elements[0].text.strip() if len(dd_elements) > 0 else ""
            사고장소 = dd_elements[1].text.strip() if len(dd_elements) > 1 else ""
            조회기간 = dd_elements[2].text.strip() if len(dd_elements) > 2 else ""

            excel_btn = wait.until(EC.element_to_be_clickable(
                (By.CSS_SELECTOR, "#new_popup > div.pop_cont > div.btn_box > a.btn.exbtn")
            ))
            excel_btn.click()

            downloaded_file = wait_for_download_complete()
            if downloaded_file:
                downloaded_path = os.path.join(DOWNLOAD_DIR, downloaded_file)
                last_size = -1
                for _ in range(5):
                    if os.path.exists(downloaded_path):
                        current_size = os.path.getsize(downloaded_path)
                        if current_size > 0 and current_size == last_size:
                            break
                        last_size = current_size
                    time.sleep(1)

                df = pd.read_excel(downloaded_path, header=[0, 1, 2])
                if isinstance(df.columns, pd.MultiIndex):
                    df.columns = ['_'.join([str(c).strip() for c in col if str(c).strip() not in ('nan', '')]) for col in df.columns]
                else:
                    df.columns = [str(c).strip() for c in df.columns]
                df.columns = [col.strip() for col in df.columns]
                df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
                df.insert(0, '사고지역', 사고지역)
                df.insert(1, '사고장소', 사고장소)
                df.insert(2, '조회기간', 조회기간)
                logging.info(f"[✅ 성공] 데이터 수집 완료 (key: {key})")
                try:
                    os.remove(downloaded_path)
                except OSError as e:
                    logging.error(f"[❌ 삭제 실패] 다운로드된 파일 삭제 실패: {e}")
                return df
            else:
                logging.warning(f"[⚠️ 타임아웃] 파일 다운로드 실패 (key: {key})")
                retries += 1
                logging.warning(f"[⚠️ 재시도] 다운로드 실패 (key: {key}) (재시도 {retries}/2)")
                if len(driver.window_handles) > 1:
                    try:
                        driver.close()
                        driver.switch_to.window(main_window)
                    except Exception:
                        pass
                continue
        except Exception as e:
            retries += 1
            logging.error(f"[❌ 실패] 다운로드 처리 중 오류 발생 (key: {key}) - {e} (재시도 {retries}/2)")
            driver.save_screenshot(f"error_{key}.png")
            time.sleep(1)
        finally:
            if len(driver.window_handles) > 1:
                try:
                    driver.close()
                except Exception:
                    pass
            driver.switch_to.window(main_window) # <--- 이 부분이 핵심
    
    if retries == 2:
        logging.error(f"[⛔ 완전 실패] 다운로드 처리 완전 실패 (key: {key})")
    return None

# ---------------------- visited ----------------------
visited = set()

# ---------------------- 버튼 클릭 + 내부 스크롤 ----------------------
def download_page(driver, wait, year_value, sido_text, jijace_text):
    scroll_element = driver.find_element(By.CSS_SELECTOR, ".rMateH5__VBrowserScrollBar")
    last_scroll_height = -1
    scroll_count = 0
    
    current_page_dfs = []

    while True:
        buttons = driver.find_elements(By.CSS_SELECTOR, "#rMateH5__Content69 > div > span > img")
        
        if not buttons:
            logging.info(f"[{sido_text}_{jijace_text}] 버튼 없음 → 종료")
            break

        logging.info(f"[{sido_text}_{jijace_text}] 스크롤 {scroll_count}회차 시작. 현재 DOM에 있는 버튼 수: {len(buttons)}개.")

        for idx, btn in enumerate(buttons):
            key = f"{year_value}_{sido_text}_{jijace_text}_scroll{scroll_count}_idx{idx}"

            if key in visited:
                continue

            try:
                button_cell = btn.find_element(By.XPATH, "./ancestor::div[contains(@class, 'rMateH5__ImageItemRenderer')]")
                parent_container = button_cell.find_element(By.XPATH, "./parent::div")
                branch_name = parent_container.find_element(By.CSS_SELECTOR, "span.rMateH5__DataGridColumn25").text.strip()
                incident_count = parent_container.find_element(By.CSS_SELECTOR, "span.rMateH5__DataGridColumn27").text.strip()
            except StaleElementReferenceException:
                logging.warning(f"[{sido_text}_{jijace_text}] StaleElementReferenceException 발생. 루프 재시작.")
                buttons = driver.find_elements(By.CSS_SELECTOR, "#rMateH5__Content69 > div > span > img")
                continue
            except Exception as e:
                logging.error(f"[{sido_text}_{jijace_text}] [❌ 데이터 파싱 실패] {e} (key: {key})")
                continue

            if branch_name == '합계':
                logging.info(f"[{sido_text}_{jijace_text}] 🚫 건너뛰기: '{branch_name}' 항목은 처리하지 않습니다.")
                visited.add(key)
                continue

            logging.info(f"[{sido_text}_{jijace_text}] 👉 클릭: '{branch_name}' (사고수: {incident_count}) (key: {key})")

            driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", btn)
            time.sleep(1)
            driver.execute_script("arguments[0].click();", btn)
            time.sleep(1)

            df = handle_structure_download(driver, wait, key)
            if df is not None:
                current_page_dfs.append(df)
                visited.add(key)
            else:
                visited.add(key)
        
        current_scroll = driver.execute_script("return arguments[0].scrollTop;", scroll_element)
        max_scroll = driver.execute_script("return arguments[0].scrollHeight - arguments[0].clientHeight;", scroll_element)
        
        if current_scroll >= max_scroll:
            logging.info(f"[{sido_text}_{jijace_text}] 📌 스크롤 끝. 현재까지 총 {len(current_page_dfs)}건 수집 완료.")
            break

        if current_scroll == last_scroll_height: 
            logging.warning(f"[{sido_text}_{jijace_text}] 스크롤 위치 변화 없음. 추가 콘텐츠 로딩 대기 시도. (3초)")
            time.sleep(3)
            current_scroll_after_wait = driver.execute_script("return arguments[0].scrollTop;", scroll_element)
            if current_scroll_after_wait == last_scroll_height:
                logging.error(f"[{sido_text}_{jijace_text}] ⛔️ 스크롤 위치 변화 없음 및 추가 대기 후에도 동일 → 현재 지자체 처리 강제 종료")
                break
        
        last_scroll_height = current_scroll
        scroll_count += 1
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + 400;", scroll_element)
        logging.info(f"[{sido_text}_{jijace_text}] 스크롤 다운...")
        time.sleep(1)

    logging.info(f"[{sido_text}_{jijace_text}] ✅ 이 지자체의 모든 버튼 다운로드 완료")
    return current_page_dfs

# ---------------------- 전체 다운로드 ----------------------
def download_all(driver, wait, year_value, sido_text, jijace_text):
    return download_page(driver, wait, year_value, sido_text, jijace_text)

# ---------------------- 실행 ----------------------
test_years = ["2018"]
all_collected_dfs = []
try:
    for year_value in test_years:
        logging.info(f"\n--- {year_value}년도 데이터 수집 시작 ---")
        year_select = Select(driver.find_element(By.ID, "Year"))
        year_select.select_by_value(year_value)

        sido_options = driver.find_elements(By.CSS_SELECTOR, "#sido option")
        for sido_index in range(1, len(sido_options)):
            sido_select = Select(driver.find_element(By.ID, "sido"))
            sido_select.select_by_index(sido_index)
            sido_text = sido_select.first_selected_option.text
            
            logging.info(f"\n--- {year_value}년 {sido_text} 데이터 수집 시작 ---")
            
            wait.until(EC.presence_of_element_located((By.ID, "jijace")))
            jijace_select = Select(driver.find_element(By.ID, "jijace"))
            jijace_select.select_by_index(0)
            jijace_text = jijace_select.first_selected_option.text
            time.sleep(0.5)

            wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, "div.btn_wrap > a")))
            search_button = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "div.btn_wrap > a")))
            driver.execute_script("arguments[0].click();", search_button)

            try:
                alert = driver.switch_to.alert
                alert.accept()
            except NoAlertPresentException:
                pass

            time.sleep(3)
            jijace_dfs = download_all(driver, wait, year_value, sido_text, jijace_text)
            if jijace_dfs:
                all_collected_dfs.extend(jijace_dfs)
        
        logging.info(f"--- {year_value}년도 데이터 수집 완료 ---")
        time.sleep(5)

finally:
    driver.quit()

# ---------------------- 수집된 DF 확인 및 처리 ----------------------
logging.info("\n--- 스크래핑 후 데이터 처리 시작 ---")

if all_collected_dfs:
    logging.info(f"총 수집된 DataFrame 개수: {len(all_collected_dfs)}")
    final_df = pd.concat(all_collected_dfs, ignore_index=True)
    logging.info(f"모든 DataFrame을 합친 최종 DataFrame의 총 행 수: {len(final_df)}")
    
    initial_rows = len(final_df)
    final_df.drop_duplicates(inplace=True)
    rows_after_dedup = len(final_df)
    logging.info(f"중복 제거 전 행 수: {initial_rows}")
    logging.info(f"중복 제거 후 행 수: {rows_after_dedup}")
    logging.info(f"제거된 중복 행 수: {initial_rows - rows_after_dedup}")

    output_excel_path = os.path.join(DOWNLOAD_DIR, "사고데이터_통합본.xlsx")
    final_df.to_excel(output_excel_path, index=False)
    logging.info(f"✅ 최종 데이터가 '{output_excel_path}' 파일로 저장되었습니다.")
else:
    logging.info("수집된 DataFrame이 없어 최종 처리할 데이터가 없습니다.")

logging.info("\n--- 스크래핑 및 데이터 처리 완료 ---")
# Out:
# 2025-08-07 17:47:39,537 - INFO -
# --- 2018년도 데이터 수집 시작 ---
# 2025-08-07 17:47:39,537 - INFO -
# --- 2018년도 데이터 수집 시작 ---
# 2025-08-07 17:47:39,706 - INFO -
# --- 2018년 서울 데이터 수집 시작 ---
# 2025-08-07 17:47:39,706 - INFO -
# --- 2018년 서울 데이터 수집 시작 ---
# 2025-08-07 17:47:43,289 - INFO - [서울_전체] 스크롤 0회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:47:43,289 - INFO - [서울_전체] 스크롤 0회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:47:43,325 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx0)
# 2025-08-07 17:47:43,325 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:47:54,013 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx0)
# 2025-08-07 17:47:54,013 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx0)
# 2025-08-07 17:47:54,109 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx1)
# 2025-08-07 17:47:54,109 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:48:04,683 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx1)
# 2025-08-07 17:48:04,683 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx1)
# 2025-08-07 17:48:04,781 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx2)
# 2025-08-07 17:48:04,781 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:48:15,416 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx2)
# 2025-08-07 17:48:15,416 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx2)
# 2025-08-07 17:48:15,512 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx3)
# 2025-08-07 17:48:15,512 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:48:26,126 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx3)
# 2025-08-07 17:48:26,126 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx3)
# 2025-08-07 17:48:26,234 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx4)
# 2025-08-07 17:48:26,234 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:48:36,849 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx4)
# 2025-08-07 17:48:36,849 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx4)
# 2025-08-07 17:48:36,945 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx5)
# 2025-08-07 17:48:36,945 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:48:47,517 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx5)
# 2025-08-07 17:48:47,517 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx5)
# 2025-08-07 17:48:47,606 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx6)
# 2025-08-07 17:48:47,606 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:48:58,187 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx6)
# 2025-08-07 17:48:58,187 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx6)
# 2025-08-07 17:48:58,283 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx7)
# 2025-08-07 17:48:58,283 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:49:08,878 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx7)
# 2025-08-07 17:49:08,878 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx7)
# 2025-08-07 17:49:08,959 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx8)
# 2025-08-07 17:49:08,959 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:49:19,580 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx8)
# 2025-08-07 17:49:19,580 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx8)
# 2025-08-07 17:49:19,661 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx9)
# 2025-08-07 17:49:19,661 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:49:30,219 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx9)
# 2025-08-07 17:49:30,219 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx9)
# 2025-08-07 17:49:30,307 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx10)
# 2025-08-07 17:49:30,307 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:49:40,865 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx10)
# 2025-08-07 17:49:40,865 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx10)
# 2025-08-07 17:49:40,949 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx11)
# 2025-08-07 17:49:40,949 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:49:51,534 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx11)
# 2025-08-07 17:49:51,534 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx11)
# 2025-08-07 17:49:51,616 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx12)
# 2025-08-07 17:49:51,616 - INFO - [서울_전체] 👉 클릭: '수서역사거리' (사고수: 64) (key: 2018_서울_전체_scroll0_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:50:02,196 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx12)
# 2025-08-07 17:50:02,196 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll0_idx12)
# 2025-08-07 17:50:02,266 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:50:02,266 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:50:03,277 - INFO - [서울_전체] 스크롤 1회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:50:03,277 - INFO - [서울_전체] 스크롤 1회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:50:03,301 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx0)
# 2025-08-07 17:50:03,301 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:50:13,970 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx0)
# 2025-08-07 17:50:13,970 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx0)
# 2025-08-07 17:50:14,049 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx1)
# 2025-08-07 17:50:14,049 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:50:24,675 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx1)
# 2025-08-07 17:50:24,675 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx1)
# 2025-08-07 17:50:24,772 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx2)
# 2025-08-07 17:50:24,772 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:50:35,396 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx2)
# 2025-08-07 17:50:35,396 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx2)
# 2025-08-07 17:50:35,483 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx3)
# 2025-08-07 17:50:35,483 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:50:46,075 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx3)
# 2025-08-07 17:50:46,075 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx3)
# 2025-08-07 17:50:46,169 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx4)
# 2025-08-07 17:50:46,169 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:50:56,779 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx4)
# 2025-08-07 17:50:56,779 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx4)
# 2025-08-07 17:50:56,871 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx5)
# 2025-08-07 17:50:56,871 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:51:07,477 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx5)
# 2025-08-07 17:51:07,477 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx5)
# 2025-08-07 17:51:07,568 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx6)
# 2025-08-07 17:51:07,568 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:51:18,201 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx6)
# 2025-08-07 17:51:18,201 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx6)
# 2025-08-07 17:51:18,288 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx7)
# 2025-08-07 17:51:18,288 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:51:28,890 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx7)
# 2025-08-07 17:51:28,890 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx7)
# 2025-08-07 17:51:28,985 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx8)
# 2025-08-07 17:51:28,985 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:51:39,580 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx8)
# 2025-08-07 17:51:39,580 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx8)
# 2025-08-07 17:51:39,672 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx9)
# 2025-08-07 17:51:39,672 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:51:50,274 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx9)
# 2025-08-07 17:51:50,274 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx9)
# 2025-08-07 17:51:50,366 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx10)
# 2025-08-07 17:51:50,366 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:52:00,958 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx10)
# 2025-08-07 17:52:00,958 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx10)
# 2025-08-07 17:52:01,053 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx11)
# 2025-08-07 17:52:01,053 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:52:11,721 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx11)
# 2025-08-07 17:52:11,721 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx11)
# 2025-08-07 17:52:11,805 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx12)
# 2025-08-07 17:52:11,805 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll1_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:52:22,439 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx12)
# 2025-08-07 17:52:22,439 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll1_idx12)
# 2025-08-07 17:52:22,510 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:52:22,510 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:52:23,524 - INFO - [서울_전체] 스크롤 2회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:52:23,524 - INFO - [서울_전체] 스크롤 2회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:52:23,550 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx0)
# 2025-08-07 17:52:23,550 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:52:34,128 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx0)
# 2025-08-07 17:52:34,128 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx0)
# 2025-08-07 17:52:34,215 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx1)
# 2025-08-07 17:52:34,215 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:52:44,818 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx1)
# 2025-08-07 17:52:44,818 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx1)
# 2025-08-07 17:52:44,915 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx2)
# 2025-08-07 17:52:44,915 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:52:55,543 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx2)
# 2025-08-07 17:52:55,543 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx2)
# 2025-08-07 17:52:55,633 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx3)
# 2025-08-07 17:52:55,633 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:53:06,213 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx3)
# 2025-08-07 17:53:06,213 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx3)
# 2025-08-07 17:53:06,305 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx4)
# 2025-08-07 17:53:06,305 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:53:16,878 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx4)
# 2025-08-07 17:53:16,878 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx4)
# 2025-08-07 17:53:16,970 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx5)
# 2025-08-07 17:53:16,970 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:53:27,563 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx5)
# 2025-08-07 17:53:27,563 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx5)
# 2025-08-07 17:53:27,655 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx6)
# 2025-08-07 17:53:27,655 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:53:38,246 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx6)
# 2025-08-07 17:53:38,246 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx6)
# 2025-08-07 17:53:38,335 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx7)
# 2025-08-07 17:53:38,335 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:53:48,996 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx7)
# 2025-08-07 17:53:48,996 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx7)
# 2025-08-07 17:53:49,085 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx8)
# 2025-08-07 17:53:49,085 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:53:59,670 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx8)
# 2025-08-07 17:53:59,670 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx8)
# 2025-08-07 17:53:59,759 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx9)
# 2025-08-07 17:53:59,759 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:54:10,365 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx9)
# 2025-08-07 17:54:10,365 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx9)
# 2025-08-07 17:54:10,484 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx10)
# 2025-08-07 17:54:10,484 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:54:21,110 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx10)
# 2025-08-07 17:54:21,110 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx10)
# 2025-08-07 17:54:21,202 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx11)
# 2025-08-07 17:54:21,202 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:54:31,801 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx11)
# 2025-08-07 17:54:31,801 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx11)
# 2025-08-07 17:54:31,894 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx12)
# 2025-08-07 17:54:31,894 - INFO - [서울_전체] 👉 클릭: '신논현역 사거리' (사고수: 11) (key: 2018_서울_전체_scroll2_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:54:42,460 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx12)
# 2025-08-07 17:54:42,460 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll2_idx12)
# 2025-08-07 17:54:42,538 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:54:42,538 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:54:43,550 - INFO - [서울_전체] 스크롤 3회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:54:43,550 - INFO - [서울_전체] 스크롤 3회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:54:43,575 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx0)
# 2025-08-07 17:54:43,575 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:54:54,140 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx0)
# 2025-08-07 17:54:54,140 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx0)
# 2025-08-07 17:54:54,233 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx1)
# 2025-08-07 17:54:54,233 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:55:04,787 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx1)
# 2025-08-07 17:55:04,787 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx1)
# 2025-08-07 17:55:04,879 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx2)
# 2025-08-07 17:55:04,879 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:55:15,456 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx2)
# 2025-08-07 17:55:15,456 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx2)
# 2025-08-07 17:55:15,546 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx3)
# 2025-08-07 17:55:15,546 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:55:26,168 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx3)
# 2025-08-07 17:55:26,168 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx3)
# 2025-08-07 17:55:26,262 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx4)
# 2025-08-07 17:55:26,262 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:55:36,845 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx4)
# 2025-08-07 17:55:36,845 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx4)
# 2025-08-07 17:55:36,934 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx5)
# 2025-08-07 17:55:36,934 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:55:47,499 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx5)
# 2025-08-07 17:55:47,499 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx5)
# 2025-08-07 17:55:47,591 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx6)
# 2025-08-07 17:55:47,591 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:55:58,175 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx6)
# 2025-08-07 17:55:58,175 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx6)
# 2025-08-07 17:55:58,268 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx7)
# 2025-08-07 17:55:58,268 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:56:08,841 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx7)
# 2025-08-07 17:56:08,841 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx7)
# 2025-08-07 17:56:08,927 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx8)
# 2025-08-07 17:56:08,927 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:56:19,498 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx8)
# 2025-08-07 17:56:19,498 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx8)
# 2025-08-07 17:56:19,580 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx9)
# 2025-08-07 17:56:19,580 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:56:30,185 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx9)
# 2025-08-07 17:56:30,185 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx9)
# 2025-08-07 17:56:30,281 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx10)
# 2025-08-07 17:56:30,281 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:56:40,874 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx10)
# 2025-08-07 17:56:40,874 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx10)
# 2025-08-07 17:56:40,966 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx11)
# 2025-08-07 17:56:40,966 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:56:51,558 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx11)
# 2025-08-07 17:56:51,558 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx11)
# 2025-08-07 17:56:51,643 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx12)
# 2025-08-07 17:56:51,643 - INFO - [서울_전체] 👉 클릭: '강동성심병원 사거리(남동)' (사고수: 17) (key: 2018_서울_전체_scroll3_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:57:02,243 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx12)
# 2025-08-07 17:57:02,243 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll3_idx12)
# 2025-08-07 17:57:02,309 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:57:02,309 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:57:03,324 - INFO - [서울_전체] 스크롤 4회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:57:03,324 - INFO - [서울_전체] 스크롤 4회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:57:03,348 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx0)
# 2025-08-07 17:57:03,348 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:57:13,936 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx0)
# 2025-08-07 17:57:13,936 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx0)
# 2025-08-07 17:57:14,022 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx1)
# 2025-08-07 17:57:14,022 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:57:24,593 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx1)
# 2025-08-07 17:57:24,593 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx1)
# 2025-08-07 17:57:24,679 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx2)
# 2025-08-07 17:57:24,679 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:57:35,253 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx2)
# 2025-08-07 17:57:35,253 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx2)
# 2025-08-07 17:57:35,342 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx3)
# 2025-08-07 17:57:35,342 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:57:45,938 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx3)
# 2025-08-07 17:57:45,938 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx3)
# 2025-08-07 17:57:46,018 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx4)
# 2025-08-07 17:57:46,018 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:57:56,634 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx4)
# 2025-08-07 17:57:56,634 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx4)
# 2025-08-07 17:57:56,719 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx5)
# 2025-08-07 17:57:56,719 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:58:07,346 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx5)
# 2025-08-07 17:58:07,346 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx5)
# 2025-08-07 17:58:07,441 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx6)
# 2025-08-07 17:58:07,441 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:58:18,063 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx6)
# 2025-08-07 17:58:18,063 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx6)
# 2025-08-07 17:58:18,149 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx7)
# 2025-08-07 17:58:18,149 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:58:28,757 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx7)
# 2025-08-07 17:58:28,757 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx7)
# 2025-08-07 17:58:28,848 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx8)
# 2025-08-07 17:58:28,848 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:58:39,440 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx8)
# 2025-08-07 17:58:39,440 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx8)
# 2025-08-07 17:58:39,525 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx9)
# 2025-08-07 17:58:39,525 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:58:50,088 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx9)
# 2025-08-07 17:58:50,088 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx9)
# 2025-08-07 17:58:50,173 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx10)
# 2025-08-07 17:58:50,173 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:59:00,751 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx10)
# 2025-08-07 17:59:00,751 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx10)
# 2025-08-07 17:59:00,843 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx11)
# 2025-08-07 17:59:00,843 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:59:11,415 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx11)
# 2025-08-07 17:59:11,415 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx11)
# 2025-08-07 17:59:11,498 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx12)
# 2025-08-07 17:59:11,498 - INFO - [서울_전체] 👉 클릭: '동신중 사거리(남서)' (사고수: 24) (key: 2018_서울_전체_scroll4_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:59:22,092 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx12)
# 2025-08-07 17:59:22,092 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll4_idx12)
# 2025-08-07 17:59:22,169 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:59:22,169 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 17:59:23,177 - INFO - [서울_전체] 스크롤 5회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:59:23,177 - INFO - [서울_전체] 스크롤 5회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 17:59:23,200 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx0)
# 2025-08-07 17:59:23,200 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:59:33,791 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx0)
# 2025-08-07 17:59:33,791 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx0)
# 2025-08-07 17:59:33,879 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx1)
# 2025-08-07 17:59:33,879 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:59:44,512 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx1)
# 2025-08-07 17:59:44,512 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx1)
# 2025-08-07 17:59:44,595 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx2)
# 2025-08-07 17:59:44,595 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 17:59:55,200 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx2)
# 2025-08-07 17:59:55,200 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx2)
# 2025-08-07 17:59:55,287 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx3)
# 2025-08-07 17:59:55,287 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:00:05,898 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx3)
# 2025-08-07 18:00:05,898 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx3)
# 2025-08-07 18:00:05,985 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx4)
# 2025-08-07 18:00:05,985 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:00:16,633 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx4)
# 2025-08-07 18:00:16,633 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx4)
# 2025-08-07 18:00:16,716 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx5)
# 2025-08-07 18:00:16,716 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:00:27,315 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx5)
# 2025-08-07 18:00:27,315 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx5)
# 2025-08-07 18:00:27,409 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx6)
# 2025-08-07 18:00:27,409 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:00:37,979 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx6)
# 2025-08-07 18:00:37,979 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx6)
# 2025-08-07 18:00:38,063 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx7)
# 2025-08-07 18:00:38,063 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:00:48,649 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx7)
# 2025-08-07 18:00:48,649 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx7)
# 2025-08-07 18:00:48,742 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx8)
# 2025-08-07 18:00:48,742 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:00:59,324 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx8)
# 2025-08-07 18:00:59,324 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx8)
# 2025-08-07 18:00:59,420 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx9)
# 2025-08-07 18:00:59,420 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:01:10,008 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx9)
# 2025-08-07 18:01:10,008 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx9)
# 2025-08-07 18:01:10,105 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx10)
# 2025-08-07 18:01:10,105 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:01:20,723 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx10)
# 2025-08-07 18:01:20,723 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx10)
# 2025-08-07 18:01:20,814 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx11)
# 2025-08-07 18:01:20,814 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:01:31,382 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx11)
# 2025-08-07 18:01:31,382 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx11)
# 2025-08-07 18:01:31,480 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx12)
# 2025-08-07 18:01:31,480 - INFO - [서울_전체] 👉 클릭: '미아사거리(숭곡중 북서)' (사고수: 36) (key: 2018_서울_전체_scroll5_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:01:42,117 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx12)
# 2025-08-07 18:01:42,117 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll5_idx12)
# 2025-08-07 18:01:42,188 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 18:01:42,188 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 18:01:43,204 - INFO - [서울_전체] 스크롤 6회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 18:01:43,204 - INFO - [서울_전체] 스크롤 6회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 18:01:43,227 - INFO - [서울_전체] 👉 클릭: '번동사거리(서울수송중)' (사고수: 38) (key: 2018_서울_전체_scroll6_idx0)
# 2025-08-07 18:01:43,227 - INFO - [서울_전체] 👉 클릭: '번동사거리(서울수송중)' (사고수: 38) (key: 2018_서울_전체_scroll6_idx0)
# ...
# 2025-08-07 18:12:17,085 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx6)
# 2025-08-07 18:12:17,085 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx6)
# 2025-08-07 18:12:17,182 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx7)
# 2025-08-07 18:12:17,182 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:12:27,811 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx7)
# 2025-08-07 18:12:27,811 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx7)
# 2025-08-07 18:12:27,896 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx8)
# 2025-08-07 18:12:27,896 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:12:38,485 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx8)
# 2025-08-07 18:12:38,485 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx8)
# 2025-08-07 18:12:38,582 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx9)
# 2025-08-07 18:12:38,582 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:12:49,140 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx9)
# 2025-08-07 18:12:49,140 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx9)
# 2025-08-07 18:12:49,228 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx10)
# 2025-08-07 18:12:49,228 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:12:59,769 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx10)
# 2025-08-07 18:12:59,769 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx10)
# 2025-08-07 18:12:59,853 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx11)
# 2025-08-07 18:12:59,853 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:13:10,416 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx11)
# 2025-08-07 18:13:10,416 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx11)
# 2025-08-07 18:13:10,508 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx12)
# 2025-08-07 18:13:10,508 - INFO - [서울_전체] 👉 클릭: '염창역 사거리(2번출구)' (사고수: 18) (key: 2018_서울_전체_scroll10_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:13:21,104 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx12)
# 2025-08-07 18:13:21,104 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll10_idx12)
# 2025-08-07 18:13:21,198 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 18:13:21,198 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 18:13:22,211 - INFO - [서울_전체] 스크롤 11회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 18:13:22,211 - INFO - [서울_전체] 스크롤 11회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 18:13:22,242 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx0)
# 2025-08-07 18:13:22,242 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:13:32,826 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx0)
# 2025-08-07 18:13:32,826 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx0)
# 2025-08-07 18:13:32,908 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx1)
# 2025-08-07 18:13:32,908 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:13:43,468 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx1)
# 2025-08-07 18:13:43,468 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx1)
# 2025-08-07 18:13:43,558 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx2)
# 2025-08-07 18:13:43,558 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:13:54,106 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx2)
# 2025-08-07 18:13:54,106 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx2)
# 2025-08-07 18:13:54,190 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx3)
# 2025-08-07 18:13:54,190 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:14:04,767 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx3)
# 2025-08-07 18:14:04,767 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx3)
# 2025-08-07 18:14:04,864 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx4)
# 2025-08-07 18:14:04,864 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx4)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:14:15,432 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx4)
# 2025-08-07 18:14:15,432 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx4)
# 2025-08-07 18:14:15,517 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx5)
# 2025-08-07 18:14:15,517 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx5)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:14:26,106 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx5)
# 2025-08-07 18:14:26,106 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx5)
# 2025-08-07 18:14:26,197 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx6)
# 2025-08-07 18:14:26,197 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx6)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:14:36,792 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx6)
# 2025-08-07 18:14:36,792 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx6)
# 2025-08-07 18:14:36,888 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx7)
# 2025-08-07 18:14:36,888 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx7)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:14:47,462 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx7)
# 2025-08-07 18:14:47,462 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx7)
# 2025-08-07 18:14:47,546 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx8)
# 2025-08-07 18:14:47,546 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx8)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:14:58,143 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx8)
# 2025-08-07 18:14:58,143 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx8)
# 2025-08-07 18:14:58,228 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx9)
# 2025-08-07 18:14:58,228 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx9)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:15:08,804 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx9)
# 2025-08-07 18:15:08,804 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx9)
# 2025-08-07 18:15:08,889 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx10)
# 2025-08-07 18:15:08,889 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx10)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:15:19,461 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx10)
# 2025-08-07 18:15:19,461 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx10)
# 2025-08-07 18:15:19,564 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx11)
# 2025-08-07 18:15:19,564 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx11)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:15:30,128 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx11)
# 2025-08-07 18:15:30,128 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx11)
# 2025-08-07 18:15:30,216 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx12)
# 2025-08-07 18:15:30,216 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll11_idx12)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:15:40,797 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx12)
# 2025-08-07 18:15:40,797 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll11_idx12)
# 2025-08-07 18:15:40,895 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 18:15:40,895 - INFO - [서울_전체] 스크롤 다운...
# 2025-08-07 18:15:41,904 - INFO - [서울_전체] 스크롤 12회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 18:15:41,904 - INFO - [서울_전체] 스크롤 12회차 시작. 현재 DOM에 있는 버튼 수: 13개.
# 2025-08-07 18:15:41,941 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx0)
# 2025-08-07 18:15:41,941 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx0)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:15:52,530 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx0)
# 2025-08-07 18:15:52,530 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx0)
# 2025-08-07 18:15:52,623 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx1)
# 2025-08-07 18:15:52,623 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx1)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:16:03,184 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx1)
# 2025-08-07 18:16:03,184 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx1)
# 2025-08-07 18:16:03,270 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx2)
# 2025-08-07 18:16:03,270 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx2)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:16:13,818 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx2)
# 2025-08-07 18:16:13,818 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx2)
# 2025-08-07 18:16:13,915 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx3)
# 2025-08-07 18:16:13,915 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx3)
# c:\Users\USER\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-07 18:16:24,478 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx3)
# 2025-08-07 18:16:24,478 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2018_서울_전체_scroll12_idx3)
# 2025-08-07 18:16:24,559 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx4)
# 2025-08-07 18:16:24,559 - INFO - [서울_전체] 👉 클릭: '미림여고입구(신성초 부근)' (사고수: 30) (key: 2018_서울_전체_scroll12_idx4)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 258
#     255     pass
#     257 time.sleep(3)
# --> 258 jijace_dfs = download_all(driver, wait, year_value, sido_text, jijace_text)
#     259 if jijace_dfs:
#     260     all_collected_dfs.extend(jijace_dfs)
#
# Cell In[2], line 222, in download_all(driver, wait, year_value, sido_text, jijace_text)
#     221 def download_all(driver, wait, year_value, sido_text, jijace_text):
# --> 222     return download_page(driver, wait, year_value, sido_text, jijace_text)
#
# Cell In[2], line 189, in download_page(driver, wait, year_value, sido_text, jijace_text)
#     186 driver.execute_script("arguments[0].click();", btn)
#     187 time.sleep(1)
# --> 189 df = handle_structure_download(driver, wait, key)
#     190 if df is not None:
#     191     current_page_dfs.append(df)
#
# Cell In[2], line 69, in handle_structure_download(driver, wait, key)
#      67 tab = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#tabId03")))
#      68 tab.click()
# ---> 69 time.sleep(5)
#      71 wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "dl.jogun dd")))
#      72 dd_elements = driver.find_elements(By.CSS_SELECTOR, "dl.jogun dd")
#
# KeyboardInterrupt:
