# %%
import os
import time
import pandas as pd
import logging
import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoAlertPresentException, TimeoutException, StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.chrome.options import Options

# ---------------------- 로그 설정 ----------------------
log_file_name = f"crawling_log_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
logging.basicConfig(
    filename=log_file_name,
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    encoding='utf-8'
)
console_handler = logging.StreamHandler()
console_handler.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))
logging.getLogger().addHandler(console_handler)

DOWNLOAD_DIR = r"C:\Users\USER\Downloads"
options = Options()
options.add_experimental_option("detach", True)
options.add_experimental_option("prefs", {
    "download.default_directory": DOWNLOAD_DIR,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "plugins.always_open_pdf_externally": True
})

driver = webdriver.Chrome(options=options)
driver.get("https://tmacs.kotsa.or.kr/web/TG/TG300/TG3100/Tg2127.jsp?mid=S1810")
wait = WebDriverWait(driver, 15)

# ---------------------- 팝업 / 다운로드 ----------------------
def wait_for_download_complete(download_dir=DOWNLOAD_DIR, timeout=180):
    before = set(os.listdir(download_dir))
    end_time = time.time() + timeout
    while time.time() < end_time:
        after = set(os.listdir(download_dir))
        new_files = after - before
        if new_files and any(f.endswith((".xlsx", ".xls")) for f in new_files):
            for f in new_files:
                if (f.endswith(".xlsx") or f.endswith(".xls")) and not f.startswith("~"):
                    return f
        time.sleep(1)
     # 타임아웃 오류 메시지 추가
    raise TimeoutError(f"파일 다운로드 시간 초과. {timeout}초 내에 .xlsx 또는 .xls 파일을 찾을 수 없습니다.")


def handle_structure_download(driver, wait, key):
    main_window = driver.current_window_handle
    retries = 0
    while retries < 2:
        try:
            time.sleep(1)
            for handle in driver.window_handles:
                if handle != main_window:
                    driver.switch_to.window(handle)
                    break
            
            tab = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#tabId03")))
            tab.click()
            time.sleep(5)

            wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR, "dl.jogun dd")))
            dd_elements = driver.find_elements(By.CSS_SELECTOR, "dl.jogun dd")
            사고지역 = dd_elements[0].text.strip() if len(dd_elements) > 0 else ""
            사고장소 = dd_elements[1].text.strip() if len(dd_elements) > 1 else ""
            조회기간 = dd_elements[2].text.strip() if len(dd_elements) > 2 else ""

            excel_btn = wait.until(EC.element_to_be_clickable(
                (By.CSS_SELECTOR, "#new_popup > div.pop_cont > div.btn_box > a.btn.exbtn")
            ))
            excel_btn.click()

            downloaded_file = wait_for_download_complete()
            if downloaded_file:
                downloaded_path = os.path.join(DOWNLOAD_DIR, downloaded_file)
                last_size = -1
                for _ in range(5):
                    if os.path.exists(downloaded_path):
                        current_size = os.path.getsize(downloaded_path)
                        if current_size > 0 and current_size == last_size:
                            break
                        last_size = current_size
                    time.sleep(1)

                df = pd.read_excel(downloaded_path, header=[0, 1, 2])
                if isinstance(df.columns, pd.MultiIndex):
                    df.columns = ['_'.join([str(c).strip() for c in col if str(c).strip() not in ('nan', '')]) for col in df.columns]
                else:
                    df.columns = [str(c).strip() for c in df.columns]
                df.columns = [col.strip() for col in df.columns]
                df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
                df.insert(0, '사고지역', 사고지역)
                df.insert(1, '사고장소', 사고장소)
                df.insert(2, '조회기간', 조회기간)
                logging.info(f"[✅ 성공] 데이터 수집 완료 (key: {key})")
                try:
                    os.remove(downloaded_path)
                except OSError as e:
                    logging.error(f"[❌ 삭제 실패] 다운로드된 파일 삭제 실패: {e}")
                return df
            else:
                logging.warning(f"[⚠️ 타임아웃] 파일 다운로드 실패 (key: {key})")
                retries += 1
                logging.warning(f"[⚠️ 재시도] 다운로드 실패 (key: {key}) (재시도 {retries}/2)")
                if len(driver.window_handles) > 1:
                    try:
                        driver.close()
                        driver.switch_to.window(main_window)
                    except Exception:
                        pass
                continue
        except Exception as e:
            retries += 1
            logging.error(f"[❌ 실패] 다운로드 처리 중 오류 발생 (key: {key}) - {e} (재시도 {retries}/2)")
            driver.save_screenshot(f"error_{key}.png")
            time.sleep(1)
        finally:
            if len(driver.window_handles) > 1:
                try:
                    driver.close()
                except Exception:
                    pass
            driver.switch_to.window(main_window) # <--- 이 부분이 핵심
    
    if retries == 2:
        logging.error(f"[⛔ 완전 실패] 다운로드 처리 완전 실패 (key: {key})")
    return None

# ---------------------- visited ----------------------
visited = set()

# ---------------------- 버튼 클릭 + 내부 스크롤 ----------------------
def download_page(driver, wait, year_value, sido_text, jijace_text):
    scroll_element = driver.find_element(By.CSS_SELECTOR, ".rMateH5__VBrowserScrollBar")
    last_scroll_height = -1
    scroll_count = 0
    
    current_page_dfs = []

    while True:
        buttons = driver.find_elements(By.CSS_SELECTOR, "#rMateH5__Content69 > div > span > img")
        
        if not buttons:
            logging.info(f"[{sido_text}_{jijace_text}] 버튼 없음 → 종료")
            break

        logging.info(f"[{sido_text}_{jijace_text}] 스크롤 {scroll_count}회차 시작. 현재 DOM에 있는 버튼 수: {len(buttons)}개.")

        for idx, btn in enumerate(buttons):
            key = f"{year_value}_{sido_text}_{jijace_text}_scroll{scroll_count}_idx{idx}"

            if key in visited:
                continue

            try:
                button_cell = btn.find_element(By.XPATH, "./ancestor::div[contains(@class, 'rMateH5__ImageItemRenderer')]")
                parent_container = button_cell.find_element(By.XPATH, "./parent::div")
                branch_name = parent_container.find_element(By.CSS_SELECTOR, "span.rMateH5__DataGridColumn25").text.strip()
                incident_count = parent_container.find_element(By.CSS_SELECTOR, "span.rMateH5__DataGridColumn27").text.strip()
            except StaleElementReferenceException:
                logging.warning(f"[{sido_text}_{jijace_text}] StaleElementReferenceException 발생. 루프 재시작.")
                buttons = driver.find_elements(By.CSS_SELECTOR, "#rMateH5__Content69 > div > span > img")
                continue
            except Exception as e:
                logging.error(f"[{sido_text}_{jijace_text}] [❌ 데이터 파싱 실패] {e} (key: {key})")
                continue

            if branch_name == '합계':
                logging.info(f"[{sido_text}_{jijace_text}] 🚫 건너뛰기: '{branch_name}' 항목은 처리하지 않습니다.")
                visited.add(key)
                continue

            logging.info(f"[{sido_text}_{jijace_text}] 👉 클릭: '{branch_name}' (사고수: {incident_count}) (key: {key})")

            driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", btn)
            time.sleep(1)
            driver.execute_script("arguments[0].click();", btn)
            time.sleep(1)

            df = handle_structure_download(driver, wait, key)
            if df is not None:
                current_page_dfs.append(df)
                visited.add(key)
            else:
                visited.add(key)
        
        current_scroll = driver.execute_script("return arguments[0].scrollTop;", scroll_element)
        max_scroll = driver.execute_script("return arguments[0].scrollHeight - arguments[0].clientHeight;", scroll_element)
        
        if current_scroll >= max_scroll:
            logging.info(f"[{sido_text}_{jijace_text}] 📌 스크롤 끝. 현재까지 총 {len(current_page_dfs)}건 수집 완료.")
            break

        if current_scroll == last_scroll_height: 
            logging.warning(f"[{sido_text}_{jijace_text}] 스크롤 위치 변화 없음. 추가 콘텐츠 로딩 대기 시도. (3초)")
            time.sleep(3)
            current_scroll_after_wait = driver.execute_script("return arguments[0].scrollTop;", scroll_element)
            if current_scroll_after_wait == last_scroll_height:
                logging.error(f"[{sido_text}_{jijace_text}] ⛔️ 스크롤 위치 변화 없음 및 추가 대기 후에도 동일 → 현재 지자체 처리 강제 종료")
                break
        
        last_scroll_height = current_scroll
        scroll_count += 1
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + 400;", scroll_element)
        logging.info(f"[{sido_text}_{jijace_text}] 스크롤 다운...")
        time.sleep(1)

    logging.info(f"[{sido_text}_{jijace_text}] ✅ 이 지자체의 모든 버튼 다운로드 완료")
    return current_page_dfs

# ---------------------- 전체 다운로드 ----------------------
def download_all(driver, wait, year_value, sido_text, jijace_text):
    return download_page(driver, wait, year_value, sido_text, jijace_text)

# ---------------------- 실행 ----------------------
test_years = ["2017"]
target_sido =["제주"]
all_collected_dfs = []
try:
    for year_value in test_years:
        logging.info(f"\n--- {year_value}년도 데이터 수집 시작 ---")

        # 연도 선택
        year_select = Select(driver.find_element(By.ID, "Year"))
        year_select.select_by_value(year_value)

        # 시도 옵션 가져오기
        sido_options = driver.find_elements(By.CSS_SELECTOR, "#sido option")

        # 0번은 보통 '전체'라서 건너뜀
        for sido_index in range(1, len(sido_options)):
            # 현재 인덱스의 시도 이름
            name = sido_options[sido_index].text.strip()
            if name not in target_sido:
                continue  # 타깃 시도만 진행

            # 시도 선택 (선택 직전에 다시 Select 생성해서 stale 방지)
            sido_select = Select(driver.find_element(By.ID, "sido"))
            sido_select.select_by_index(sido_index)
            sido_text = sido_select.first_selected_option.text.strip()

            logging.info(f"\n--- {year_value}년 {sido_text} 데이터 수집 시작 ---")

            # 지자체 로드 대기
            wait.until(EC.presence_of_element_located((By.ID, "jijace")))
            jijace_select = Select(driver.find_element(By.ID, "jijace"))
            jijace_options = jijace_select.options

            # 지자체 전체 반복: 보통 0번은 '전체'라 실제 지자체는 1번부터
            for jijace_idx in range(1, len(jijace_options)):
                # 매 루프마다 새로 잡기 (stale 대비)
                jijace_select = Select(driver.find_element(By.ID, "jijace"))
                jijace_select.select_by_index(jijace_idx)
                jijace_text = jijace_select.first_selected_option.text.strip()
                time.sleep(0.3)

                # 검색 버튼 클릭
                btn = wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR, "div.btn_wrap > a")))
                driver.execute_script("arguments[0].click();", btn)

                # 알림(데이터 없음 등) 처리
                try:
                    alert = driver.switch_to.alert
                    alert.accept()
                    logging.info(f"[SKIP] {year_value}-{sido_text}-{jijace_text}: 알림창(데이터 없음)")
                    continue
                except NoAlertPresentException:
                    pass

                # 결과 로딩 대기 (필요 시 로딩 완료 요소로 대체)
                time.sleep(2.5)

                # 다운로드
                try:
                    jijace_dfs = download_all(driver, wait, year_value, sido_text, jijace_text)
                    if jijace_dfs:
                        all_collected_dfs.extend(jijace_dfs)
                        logging.info(f"[OK] {year_value}-{sido_text}-{jijace_text}: {len(jijace_dfs)}개 수집")
                    else:
                        logging.info(f"[EMPTY] {year_value}-{sido_text}-{jijace_text}")
                except StaleElementReferenceException:
                    logging.warning(f"[RETRY] {year_value}-{sido_text}-{jijace_text}: stale 발생, 1회 재시도")
                    jijace_select = Select(driver.find_element(By.ID, "jijace"))
                    jijace_select.select_by_index(jijace_idx)
                    time.sleep(0.5)
                    jijace_dfs = download_all(driver, wait, year_value, sido_text, jijace_text)
                    if jijace_dfs:
                        all_collected_dfs.extend(jijace_dfs)
                        logging.info(f"[OK/RETRIED] {year_value}-{sido_text}-{jijace_text}: {len(jijace_dfs)}개 수집")

        logging.info(f"--- {year_value}년도 데이터 수집 완료 ---")
        time.sleep(3)

finally:
    driver.quit()

# ---------------------- 수집된 DF 확인 및 처리 ----------------------
logging.info("\n--- 스크래핑 후 데이터 처리 시작 ---")

if all_collected_dfs:
    logging.info(f"총 수집된 DataFrame 개수: {len(all_collected_dfs)}")
    final_df = pd.concat(all_collected_dfs, ignore_index=True)
    logging.info(f"모든 DataFrame을 합친 최종 DataFrame의 총 행 수: {len(final_df)}")
    
    initial_rows = len(final_df)
    final_df.drop_duplicates(inplace=True)
    rows_after_dedup = len(final_df)
    logging.info(f"중복 제거 전 행 수: {initial_rows}")
    logging.info(f"중복 제거 후 행 수: {rows_after_dedup}")
    logging.info(f"제거된 중복 행 수: {initial_rows - rows_after_dedup}")

    output_excel_path = os.path.join(DOWNLOAD_DIR, "사고데이터_통합본.xlsx")
    final_df.to_excel(output_excel_path, index=False)
    logging.info(f"✅ 최종 데이터가 '{output_excel_path}' 파일로 저장되었습니다.")
else:
    logging.info("수집된 DataFrame이 없어 최종 처리할 데이터가 없습니다.")

logging.info("\n--- 스크래핑 및 데이터 처리 완료 ---")
# Out:
# 2025-08-08 17:59:01,769 - INFO -
# --- 2017년도 데이터 수집 시작 ---
# 2025-08-08 17:59:01,769 - INFO -
# --- 2017년도 데이터 수집 시작 ---
# 2025-08-08 17:59:02,086 - INFO -
# --- 2017년 제주 데이터 수집 시작 ---
# 2025-08-08 17:59:02,086 - INFO -
# --- 2017년 제주 데이터 수집 시작 ---
# 2025-08-08 17:59:05,004 - INFO - [제주_서귀포시] 스크롤 0회차 시작. 현재 DOM에 있는 버튼 수: 14개.
# 2025-08-08 17:59:05,004 - INFO - [제주_서귀포시] 스크롤 0회차 시작. 현재 DOM에 있는 버튼 수: 14개.
# 2025-08-08 17:59:05,047 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx0)
# 2025-08-08 17:59:05,047 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx0)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 17:59:16,027 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx0)
# 2025-08-08 17:59:16,027 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx0)
# 2025-08-08 17:59:16,129 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx1)
# 2025-08-08 17:59:16,129 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx1)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 17:59:26,664 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx1)
# 2025-08-08 17:59:26,664 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx1)
# 2025-08-08 17:59:26,760 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx2)
# 2025-08-08 17:59:26,760 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx2)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 17:59:37,284 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx2)
# 2025-08-08 17:59:37,284 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx2)
# 2025-08-08 17:59:37,365 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx3)
# 2025-08-08 17:59:37,365 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx3)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 17:59:47,909 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx3)
# 2025-08-08 17:59:47,909 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx3)
# 2025-08-08 17:59:47,992 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx4)
# 2025-08-08 17:59:47,992 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx4)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 17:59:58,525 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx4)
# 2025-08-08 17:59:58,525 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx4)
# 2025-08-08 17:59:58,608 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx5)
# 2025-08-08 17:59:58,608 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx5)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:00:09,108 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx5)
# 2025-08-08 18:00:09,108 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx5)
# 2025-08-08 18:00:09,201 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx6)
# 2025-08-08 18:00:09,201 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx6)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:00:19,727 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx6)
# 2025-08-08 18:00:19,727 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx6)
# 2025-08-08 18:00:19,822 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx7)
# 2025-08-08 18:00:19,822 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx7)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:00:30,411 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx7)
# 2025-08-08 18:00:30,411 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx7)
# 2025-08-08 18:00:30,505 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx8)
# 2025-08-08 18:00:30,505 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx8)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:00:41,008 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx8)
# 2025-08-08 18:00:41,008 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx8)
# 2025-08-08 18:00:41,113 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx9)
# 2025-08-08 18:00:41,113 - INFO - [제주_서귀포시] 👉 클릭: '중앙로터리(서귀포등기소 앞)' (사고수: 57) (key: 2017_제주_서귀포시_scroll0_idx9)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:00:51,669 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx9)
# 2025-08-08 18:00:51,669 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx9)
# 2025-08-08 18:00:51,789 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx10)
# 2025-08-08 18:00:51,789 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx10)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:01:02,345 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx10)
# 2025-08-08 18:01:02,345 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx10)
# 2025-08-08 18:01:02,444 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx11)
# 2025-08-08 18:01:02,444 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx11)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:01:12,910 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx11)
# 2025-08-08 18:01:12,910 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx11)
# 2025-08-08 18:01:12,992 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx12)
# 2025-08-08 18:01:12,992 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx12)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:01:23,508 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx12)
# 2025-08-08 18:01:23,508 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx12)
# 2025-08-08 18:01:23,595 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx13)
# 2025-08-08 18:01:23,595 - INFO - [제주_서귀포시] 👉 클릭: '' (사고수: ) (key: 2017_제주_서귀포시_scroll0_idx13)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:01:34,150 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx13)
# 2025-08-08 18:01:34,150 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll0_idx13)
# 2025-08-08 18:01:34,252 - INFO - [제주_서귀포시] 스크롤 다운...
# 2025-08-08 18:01:34,252 - INFO - [제주_서귀포시] 스크롤 다운...
# 2025-08-08 18:01:35,269 - INFO - [제주_서귀포시] 스크롤 1회차 시작. 현재 DOM에 있는 버튼 수: 14개.
# 2025-08-08 18:01:35,269 - INFO - [제주_서귀포시] 스크롤 1회차 시작. 현재 DOM에 있는 버튼 수: 14개.
# 2025-08-08 18:01:35,300 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx0)
# 2025-08-08 18:01:35,300 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx0)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:01:45,798 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx0)
# 2025-08-08 18:01:45,798 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx0)
# 2025-08-08 18:01:45,890 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx1)
# 2025-08-08 18:01:45,890 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx1)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:01:56,416 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx1)
# 2025-08-08 18:01:56,416 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx1)
# 2025-08-08 18:01:56,504 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx2)
# 2025-08-08 18:01:56,504 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx2)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:02:07,058 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx2)
# 2025-08-08 18:02:07,058 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx2)
# 2025-08-08 18:02:07,154 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx3)
# 2025-08-08 18:02:07,154 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx3)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:02:17,674 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx3)
# 2025-08-08 18:02:17,674 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx3)
# 2025-08-08 18:02:17,768 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx4)
# 2025-08-08 18:02:17,768 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx4)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:02:28,312 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx4)
# 2025-08-08 18:02:28,312 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx4)
# 2025-08-08 18:02:28,416 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx5)
# 2025-08-08 18:02:28,416 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx5)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:02:38,942 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx5)
# 2025-08-08 18:02:38,942 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx5)
# 2025-08-08 18:02:39,041 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx6)
# 2025-08-08 18:02:39,041 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx6)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:02:49,534 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx6)
# 2025-08-08 18:02:49,534 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx6)
# 2025-08-08 18:02:49,625 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx7)
# 2025-08-08 18:02:49,625 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx7)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:03:00,173 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx7)
# 2025-08-08 18:03:00,173 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx7)
# 2025-08-08 18:03:00,258 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx8)
# 2025-08-08 18:03:00,258 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx8)
# c:\Scoop\apps\anaconda3\2024.06-1\App\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2025-08-08 18:03:10,793 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx8)
# 2025-08-08 18:03:10,793 - INFO - [✅ 성공] 데이터 수집 완료 (key: 2017_제주_서귀포시_scroll1_idx8)
# 2025-08-08 18:03:10,889 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx9)
# 2025-08-08 18:03:10,889 - INFO - [제주_서귀포시] 👉 클릭: '대정농협 하나로마트(남쪽)' (사고수: 11) (key: 2017_제주_서귀포시_scroll1_idx9)
